# %%
import os
import pandas as pd
import matplotlib.pyplot as plt


current_dir = os.getcwd()
final_path = os.path.join(current_dir, '..', 'data', 'final', 'final.csv')

final_df = pd.read_csv(final_path)

# %%
final_df.columns
# Out:
# Index(['user_id', 'favourite_genres', 'premium_user', 'popularity_mean',
#        'popularity_std', 'popularity_mode', 'popularity_median',
#        'popularity_min', 'popularity_max', 'duration_ms_mean',
#        ...
#        'time_range', 'daily_activity', 'weekly_activity', 'monthly_activity',
#        'daily_activity_max', 'weekly_activity_max', 'monthly_activity_max',
#        'daily_activity_min', 'weekly_activity_min', 'monthly_activity_min'],
#       dtype='object', length=121)

# %% [markdown]
# ### Analiza wybranych atrybutów

# %%
final_df.hist(figsize=(16, 16), bins=100)
# Out:
# array([[<Axes: title={'center': 'user_id'}>,
#         <Axes: title={'center': 'popularity_mean'}>,
#         <Axes: title={'center': 'popularity_std'}>,
#         <Axes: title={'center': 'popularity_mode'}>,
#         <Axes: title={'center': 'popularity_median'}>,
#         <Axes: title={'center': 'popularity_min'}>,
#         <Axes: title={'center': 'popularity_max'}>,
#         <Axes: title={'center': 'duration_ms_mean'}>,
#         <Axes: title={'center': 'duration_ms_std'}>,
#         <Axes: title={'center': 'duration_ms_mode'}>],
#        [<Axes: title={'center': 'duration_ms_median'}>,
#         <Axes: title={'center': 'duration_ms_min'}>,
#         <Axes: title={'center': 'duration_ms_max'}>,
#         <Axes: title={'center': 'explicit_ratio'}>,
#         <Axes: title={'center': 'explicit_count'}>,
#         <Axes: title={'center': 'explicit_min'}>,
#         <Axes: title={'center': 'explicit_max'}>,
#         <Axes: title={'center': 'danceability_mean'}>,
#         <Axes: title={'center': 'danceability_std'}>,
#         <Axes: title={'center': 'danceability_mode'}>],
#        [<Axes: title={'center': 'danceability_median'}>,
#         <Axes: title={'center': 'danceability_min'}>,
#         <Axes: title={'center': 'danceability_max'}>,
#         <Axes: title={'center': 'energy_mean'}>,
#         <Axes: title={'center': 'energy_std'}>,
#         <Axes: title={'center': 'energy_mode'}>,
#         <Axes: title={'center': 'energy_median'}>,
#         <Axes: title={'center': 'energy_min'}>,
#         <Axes: title={'center': 'energy_max'}>,
#         <Axes: title={'center': 'loudness_mean'}>],
#        [<Axes: title={'center': 'loudness_std'}>,
#         <Axes: title={'center': 'loudness_mode'}>,
#         <Axes: title={'center': 'loudness_median'}>,
#         <Axes: title={'center': 'loudness_min'}>,
#         <Axes: title={'center': 'loudness_max'}>,
#         <Axes: title={'center': 'speechiness_mean'}>,
#         <Axes: title={'center': 'speechiness_std'}>,
#         <Axes: title={'center': 'speechiness_mode'}>,
#         <Axes: title={'center': 'speechiness_median'}>,
#         <Axes: title={'center': 'speechiness_min'}>],
#        [<Axes: title={'center': 'speechiness_max'}>,
#         <Axes: title={'center': 'acousticness_mean'}>,
#         <Axes: title={'center': 'acousticness_std'}>,
#         <Axes: title={'center': 'acousticness_mode'}>,
#         <Axes: title={'center': 'acousticness_median'}>,
#         <Axes: title={'center': 'acousticness_min'}>,
#         <Axes: title={'center': 'acousticness_max'}>,
#         <Axes: title={'center': 'instrumentalness_mean'}>,
#         <Axes: title={'center': 'instrumentalness_std'}>,
#         <Axes: title={'center': 'instrumentalness_mode'}>],
#        [<Axes: title={'center': 'instrumentalness_median'}>,
#         <Axes: title={'center': 'instrumentalness_min'}>,
#         <Axes: title={'center': 'instrumentalness_max'}>,
#         <Axes: title={'center': 'liveness_mean'}>,
#         <Axes: title={'center': 'liveness_std'}>,
#         <Axes: title={'center': 'liveness_mode'}>,
#         <Axes: title={'center': 'liveness_median'}>,
#         <Axes: title={'center': 'liveness_min'}>,
#         <Axes: title={'center': 'liveness_max'}>,
#         <Axes: title={'center': 'valence_mean'}>],
#        [<Axes: title={'center': 'valence_std'}>,
#         <Axes: title={'center': 'valence_mode'}>,
#         <Axes: title={'center': 'valence_median'}>,
#         <Axes: title={'center': 'valence_min'}>,
#         <Axes: title={'center': 'valence_max'}>,
#         <Axes: title={'center': 'tempo_mean'}>,
#         <Axes: title={'center': 'tempo_std'}>,
#         <Axes: title={'center': 'tempo_mode'}>,
#         <Axes: title={'center': 'tempo_median'}>,
#         <Axes: title={'center': 'tempo_min'}>],
#        [<Axes: title={'center': 'tempo_max'}>,
#         <Axes: title={'center': 'key_mode'}>,
#         <Axes: title={'center': 'key_median'}>,
#         <Axes: title={'center': 'key_min'}>,
#         <Axes: title={'center': 'key_max'}>,
#         <Axes: title={'center': 'mode_mode'}>,
#         <Axes: title={'center': 'mode_median'}>,
#         <Axes: title={'center': 'mode_min'}>,
#         <Axes: title={'center': 'mode_max'}>,
#         <Axes: title={'center': 'release_year_mean'}>],
#        [<Axes: title={'center': 'release_year_std'}>,
#         <Axes: title={'center': 'release_year_mode'}>,
#         <Axes: title={'center': 'release_year_median'}>,
#         <Axes: title={'center': 'release_year_min'}>,
#         <Axes: title={'center': 'release_year_max'}>,
#         <Axes: title={'center': 'time_signature_mean'}>,
#         <Axes: title={'center': 'time_signature_std'}>,
#         <Axes: title={'center': 'time_signature_mode'}>,
#         <Axes: title={'center': 'time_signature_median'}>,
#         <Axes: title={'center': 'time_signature_min'}>],
#        [<Axes: title={'center': 'time_signature_max'}>,
#         <Axes: title={'center': 'unique_artist_count'}>,
#         <Axes: title={'center': 'unique_track_count'}>,
#         <Axes: title={'center': 'city_frequency'}>,
#         <Axes: title={'center': 'skip_play_ratio'}>,
#         <Axes: title={'center': 'like_play_ratio'}>,
#         <Axes: title={'center': 'skip_like_ratio'}>,
#         <Axes: title={'center': 'skip_count'}>,
#         <Axes: title={'center': 'like_count'}>,
#         <Axes: title={'center': 'play_count'}>],
#        [<Axes: title={'center': 'session_count'}>,
#         <Axes: title={'center': 'daily_activity'}>,
#         <Axes: title={'center': 'weekly_activity'}>,
#         <Axes: title={'center': 'monthly_activity'}>,
#         <Axes: title={'center': 'daily_activity_max'}>,
#         <Axes: title={'center': 'weekly_activity_max'}>,
#         <Axes: title={'center': 'monthly_activity_max'}>,
#         <Axes: title={'center': 'daily_activity_min'}>,
#         <Axes: title={'center': 'weekly_activity_min'}>,
#         <Axes: title={'center': 'monthly_activity_min'}>]], dtype=object)

# %%
import seaborn as sns

continuous_fields = final_df.select_dtypes(include=['float64', 'int64'])
continuous_fields = continuous_fields.drop(columns=['user_id', 'key_median', 'unique_artist_count', 'unique_track_count'])

print(continuous_fields.columns)

corr_matrix = continuous_fields.corr()
plt.figure(figsize=(16, 16))
sns.heatmap(corr_matrix, cmap='coolwarm', square=True, annot=True, annot_kws={'fontsize': 7}, fmt='.0%', vmin=-1, vmax=1)
# Out:
# Index(['popularity_mean', 'popularity_std', 'popularity_mode',
#        'popularity_median', 'popularity_min', 'popularity_max',
#        'duration_ms_mean', 'duration_ms_std', 'duration_ms_mode',
#        'duration_ms_median',
#        ...
#        'session_count', 'daily_activity', 'weekly_activity',
#        'monthly_activity', 'daily_activity_max', 'weekly_activity_max',
#        'monthly_activity_max', 'daily_activity_min', 'weekly_activity_min',
#        'monthly_activity_min'],
#       dtype='object', length=106)
# <Axes: >
